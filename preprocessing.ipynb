# %% [markdown]
# #### DataPreprocessing:
# - Data preprocessing is used for improve the quality of data
#
#  - Problems in data:
#
# - insufficient data
# - Too much data
# - Missing data
# - Duplicate data
# - outliers
# - Outliers: In general term it is a data point that is significantly further away from the other data - points
#
# - Standardization(Standard Scaler)
# - RobostScalling
# - Data Range(MinMaxScaler)
# - Normalization

# %%
Standardize data:
SD is a useful technique to transform the attributes with a gaussian distribution
when data can take a any range of values it makes difficult to interpret. so, datascientists 
will convert the data into standard format
0=> mean 1=>standara diviation
standardization can be useful, and even required in some machine learning algorithms 
when your time series data has **input values with differing scales**.
This includes algorithms like Support Vector Machines, Linear and Logistic Regression, 
and other algorithms that assume or have improved performance with Gaussian data.
# Out:
#   File "<ipython-input-1-5673c11daf36>", line 1
#     Standardize data:
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df=pd.read_csv("Advertisement.csv")   # d://folder1/filename.csv
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df['TV'].isna().sum()
# Out:
# 0

# %%
df['TV'].min()
# Out:
# 0.7

# %%
df['TV'].max()
# Out:
# 296.4

# %%
df.mean()
# Out:
# TV           147.0425
# radio         23.2640
# newspaper     30.5540
# sales         14.0225
# dtype: float64

# %%
df.median()
# Out:
# TV           149.75
# radio         22.90
# newspaper     25.75
# sales         12.90
# dtype: float64

# %%
df.std()
# Out:
# TV           85.854236
# radio        14.846809
# newspaper    21.778621
# sales         5.217457
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
Visulize the data using KDE
Keranal Dencity Estimate plot is used for display the multiple samples data into one graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.title("Before scaling data")
sns.kdeplot(df['TV'])
sns.kdeplot(df['radio'])
sns.kdeplot(df['newspaper'])
sns.kdeplot(df['sales'])

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
std_data=std.fit_transform(df)
std_data
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00,
#          1.55205313e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01,
#         -6.96046111e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00,
#         -9.07405869e-01],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00,
#          8.60330287e-01],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00,
#         -2.15683025e-01],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00,
#         -1.31091086e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01,
#         -4.27042783e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01,
#         -1.58039455e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00,
#         -1.77205942e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01,
#         -6.57617064e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01,
#         -1.04190753e+00],
# ...

# %%
std_data_df=pd.DataFrame(std_data,columns=df.columns)
std_data_df.head()
# Out:
#          TV     radio  newspaper     sales
# 0  0.969852  0.981522   1.778945  1.552053
# 1 -1.197376  1.082808   0.669579 -0.696046
# 2 -1.516155  1.528463   1.783549 -0.907406
# 3  0.052050  1.217855   1.286405  0.860330
# 4  0.394182 -0.841614   1.281802 -0.215683

# %%
plt.title("After scaling data")
sns.kdeplot(std_data_df['TV'])
sns.kdeplot(std_data_df['radio'])
sns.kdeplot(std_data_df['newspaper'])
sns.kdeplot(std_data_df['sales'])

# %%
std_data_df['TV'].mean()
# Out:
# 1.1046719095020308e-16

# %%
std_data_df['TV'].std()
# Out:
# 1.002509414234171

# %%
Robost Scalling
Robost scalling also used for scale the outliers, it scale using median and Inter Quartail Range(IQR)

# %%
from sklearn.preprocessing import RobustScaler
rb=RobustScaler()
rb_data=rb.fit_transform(df)
rb_data
# Out:
# array([[ 5.56247837e-01,  5.61205273e-01,  1.34312210e+00,
#          1.30960854e+00],
#        [-7.28625822e-01,  6.17702448e-01,  5.98145286e-01,
#         -3.55871886e-01],
#        [-9.17618553e-01,  8.66290019e-01,  1.34621329e+00,
#         -5.12455516e-01],
#        [ 1.21149187e-02,  6.93032015e-01,  1.01236476e+00,
#          7.97153025e-01],
#        [ 2.14953271e-01, -4.55743879e-01,  1.00927357e+00,
#          0.00000000e+00],
#        [-9.76462444e-01,  9.79284369e-01,  1.52241113e+00,
#         -8.11387900e-01],
#        [-6.38629283e-01,  3.72881356e-01, -6.95517774e-02,
#         -1.56583630e-01],
#        [-2.04569055e-01, -1.24293785e-01, -4.37403400e-01,
#          4.27046263e-02],
#        [-9.77154725e-01, -7.83427495e-01, -7.65069552e-01,
#         -1.15302491e+00],
#        [ 3.46486674e-01, -7.64595104e-01, -1.40649150e-01,
#         -3.27402135e-01],
#        [-5.79093112e-01, -6.44067797e-01, -4.79134467e-02,
#         -6.12099644e-01],
# ...

# %%
rb_data_df=pd.DataFrame(rb_data,columns=df.columns)
rb_data_df
# Out:
#            TV     radio  newspaper     sales
# 0    0.556248  0.561205   1.343122  1.309609
# 1   -0.728626  0.617702   0.598145 -0.355872
# 2   -0.917619  0.866290   1.346213 -0.512456
# 3    0.012115  0.693032   1.012365  0.797153
# 4    0.214953 -0.455744   1.009274  0.000000
# 5   -0.976462  0.979284   1.522411 -0.811388
# 6   -0.638629  0.372881  -0.069552 -0.156584
# 7   -0.204569 -0.124294  -0.437403  0.042705
# 8   -0.977155 -0.783427  -0.765070 -1.153025
# 9    0.346487 -0.764595  -0.140649 -0.327402
# 10  -0.579093 -0.644068  -0.047913 -0.612100
# 11   0.449637  0.041431  -0.672334  0.640569
# 12  -0.871928  0.459510   1.241113 -0.526690
# 13  -0.361717 -0.576271  -0.573416 -0.455516
# 14   0.376255  0.376648   0.625966  0.868327
# 15   0.316026  0.934087   0.839258  1.352313
# 16  -0.567324  0.516008   2.727975 -0.056940
# 17   0.911388  0.629002   0.928903  1.637011
# 18  -0.557632 -0.090395  -0.230294 -0.227758
# 19  -0.016961  0.037665  -0.205564  0.241993
# ...

# %%
plt.title("After scaling data in robost scaler")
sns.kdeplot(rb_data_df['TV'])
sns.kdeplot(rb_data_df['radio'])
sns.kdeplot(rb_data_df['newspaper'])
sns.kdeplot(rb_data_df['sales'])

# %%
Range scaling(Min Max Scaller)
By using MinMaxScaller we can provide custom range for scaling the data
# Out:
#   File "<ipython-input-21-17a9abcfbb62>", line 1
#     Range scaling(Min Max Scaller)
#                 ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler(feature_range=(-1,1))
m_data=m.fit_transform(df)
m_data
# Out:
# array([[ 0.55157254,  0.52419355,  0.2119613 ,  0.61417323],
#        [-0.7037538 ,  0.58467742, -0.2119613 , -0.30708661],
#        [-0.88840041,  0.85080645,  0.21372032, -0.39370079],
#        [ 0.01995265,  0.66532258,  0.0237467 ,  0.33070866],
#        [ 0.21812648, -0.56451613,  0.02198769, -0.11023622],
#        [-0.94589111,  0.97177419,  0.31398417, -0.55905512],
#        [-0.61582685,  0.32258065, -0.59190853, -0.19685039],
#        [-0.19174839, -0.20967742, -0.80123131, -0.08661417],
#        [-0.94656747, -0.91532258, -0.9876869 , -0.7480315 ],
#        [ 0.3466351 , -0.89516129, -0.63236588, -0.29133858],
#        [-0.55765979, -0.76612903, -0.57959543, -0.4488189 ],
#        [ 0.44741292, -0.03225806, -0.93491645,  0.24409449],
#        [-0.84376057,  0.41532258,  0.15391381, -0.4015748 ],
#        [-0.34528238, -0.69354839, -0.87862797, -0.36220472],
#        [ 0.37571863,  0.3266129 , -0.19613017,  0.37007874],
# ...

# %%
m_data_df=pd.DataFrame(m_data,columns=df.columns)
m_data_df
# Out:
#            TV     radio  newspaper     sales
# 0    0.551573  0.524194   0.211961  0.614173
# 1   -0.703754  0.584677  -0.211961 -0.307087
# 2   -0.888400  0.850806   0.213720 -0.393701
# 3    0.019953  0.665323   0.023747  0.330709
# 4    0.218126 -0.564516   0.021988 -0.110236
# 5   -0.945891  0.971774   0.313984 -0.559055
# 6   -0.615827  0.322581  -0.591909 -0.196850
# 7   -0.191748 -0.209677  -0.801231 -0.086614
# 8   -0.946567 -0.915323  -0.987687 -0.748031
# 9    0.346635 -0.895161  -0.632366 -0.291339
# 10  -0.557660 -0.766129  -0.579595 -0.448819
# 11   0.447413 -0.032258  -0.934916  0.244094
# 12  -0.843761  0.415323   0.153914 -0.401575
# 13  -0.345282 -0.693548  -0.878628 -0.362205
# 14   0.375719  0.326613  -0.196130  0.370079
# 15   0.316875  0.923387  -0.074758  0.637795
# 16  -0.546162  0.475806   1.000000 -0.141732
# 17   0.898546  0.596774  -0.023747  0.795276
# 18  -0.536693 -0.173387  -0.683377 -0.236220
# 19  -0.008455 -0.036290  -0.669305  0.023622
# ...

# %%
plt.title("After scaling data using range scaler")
sns.kdeplot(m_data_df['TV'])
sns.kdeplot(m_data_df['radio'])
sns.kdeplot(m_data_df['newspaper'])
sns.kdeplot(m_data_df['sales'])

# %%
Normalization:
upto now we are scale by using features(columns)
In certain cases we want to scale the individual data observation(rows)
when clustering data we need to apply normalization

# %%
from sklearn.preprocessing import Normalizer
n=Normalizer()
n_data=n.fit_transform(df)
n_data
# Out:
# array([[0.94211621, 0.15476746, 0.28333091, 0.09048574],
#        [0.59113524, 0.52205877, 0.59910561, 0.13815296],
#        [0.20142628, 0.53752711, 0.81156054, 0.10891072],
#        [0.89863215, 0.24497365, 0.34699657, 0.10973396],
#        [0.94788063, 0.05662119, 0.30617383, 0.06763086],
#        [0.09640672, 0.54187225, 0.83109241, 0.07978487],
#        [0.80725471, 0.46048617, 0.32992149, 0.16566271],
#        [0.97684844, 0.15928643, 0.09427156, 0.10727454],
#        [0.84982063, 0.20751434, 0.09881635, 0.47431849],
#        [0.99295394, 0.01292132, 0.10535848, 0.05267924],
#        [0.92901149, 0.08151689, 0.34012221, 0.12086988],
#        [0.99043367, 0.11071452, 0.01845242, 0.08026803],
#        [0.30163094, 0.44484227, 0.83518819, 0.11659683],
#        [0.98945567, 0.0771268 , 0.0730675 , 0.09843815],
#        [0.95983344, 0.15472082, 0.21632699, 0.08935245],
#        [0.93412001, 0.22803237, 0.25289124, 0.10708438],
# ...

# %%
n_data_df=pd.DataFrame(n_data,columns=df.columns)
n_data_df.head()
# Out:
#          TV     radio  newspaper     sales
# 0  0.942116  0.154767   0.283331  0.090486
# 1  0.591135  0.522059   0.599106  0.138153
# 2  0.201426  0.537527   0.811561  0.108911
# 3  0.898632  0.244974   0.346997  0.109734
# 4  0.947881  0.056621   0.306174  0.067631

# %%
plt.title("After scaling data using normalize scaler")
sns.kdeplot(n_data_df['TV'])
sns.kdeplot(n_data_df['radio'])
sns.kdeplot(n_data_df['newspaper'])
sns.kdeplot(n_data_df['sales'])

# %% [markdown]
# #### Data cleaning

# %%
import pandas as pd 
weather_df=pd.read_csv("weather.csv")
weather_df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair

# %%
# to check null values--isnull(),isna()
weather_df.isna().sum()
# Out:
# s.no           0
# day            0
# temparature    4
# winspeed       3
# event          3
# dtype: int64

# %%
weather_df["day"][0]
# Out:
# '1/2/2019'

# %%
df=pd.read_csv("weather.csv",parse_dates=["day"])
df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1 2019-01-02         30.0      12.0     rain
# 1      1 2019-01-02          NaN      14.0      NaN
# 2      2 2019-01-03         43.0      13.0     rain
# 3      3 2019-01-04         55.0       NaN  fullair
# 4      4 2019-01-05         66.0      10.0      NaN
# 5      5 2019-01-06         34.0      15.0     cold
# 6      6 2019-01-07          NaN      17.0  fullair
# 7      7 2019-01-08         89.0       NaN     cold
# 8      8 2019-01-09          NaN       9.0  fullair
# 9      9 2019-01-10         90.0      11.0     cold
# 10    10 2019-01-11         65.0       NaN      NaN
# 11    11 2019-01-12          NaN      20.0  fullair

# %%
df.set_index('day',inplace=True)
df
# Out:
#             s.no  temparature  winspeed    event
# day
# 2019-01-02     1         30.0      12.0     rain
# 2019-01-02     1          NaN      14.0      NaN
# 2019-01-03     2         43.0      13.0     rain
# 2019-01-04     3         55.0       NaN  fullair
# 2019-01-05     4         66.0      10.0      NaN
# 2019-01-06     5         34.0      15.0     cold
# 2019-01-07     6          NaN      17.0  fullair
# 2019-01-08     7         89.0       NaN     cold
# 2019-01-09     8          NaN       9.0  fullair
# 2019-01-10     9         90.0      11.0     cold
# 2019-01-11    10         65.0       NaN      NaN
# 2019-01-12    11          NaN      20.0  fullair

# %%
df.fillna(0) # null values should filled with 0
# Out:
#             s.no  temparature  winspeed    event
# day
# 2019-01-02     1         30.0      12.0     rain
# 2019-01-02     1          0.0      14.0        0
# 2019-01-03     2         43.0      13.0     rain
# 2019-01-04     3         55.0       0.0  fullair
# 2019-01-05     4         66.0      10.0        0
# 2019-01-06     5         34.0      15.0     cold
# 2019-01-07     6          0.0      17.0  fullair
# 2019-01-08     7         89.0       0.0     cold
# 2019-01-09     8          0.0       9.0  fullair
# 2019-01-10     9         90.0      11.0     cold
# 2019-01-11    10         65.0       0.0        0
# 2019-01-12    11          0.0      20.0  fullair

# %%
column_fill=df.fillna({"temperature":0,"windspeed":0,"event":"no event"})
column_fill
# Out:
#             s.no  temparature  winspeed     event
# day
# 2019-01-02     1         30.0      12.0      rain
# 2019-01-02     1          NaN      14.0  no event
# 2019-01-03     2         43.0      13.0      rain
# 2019-01-04     3         55.0       NaN   fullair
# 2019-01-05     4         66.0      10.0  no event
# 2019-01-06     5         34.0      15.0      cold
# 2019-01-07     6          NaN      17.0   fullair
# 2019-01-08     7         89.0       NaN      cold
# 2019-01-09     8          NaN       9.0   fullair
# 2019-01-10     9         90.0      11.0      cold
# 2019-01-11    10         65.0       NaN  no event
# 2019-01-12    11          NaN      20.0   fullair

# %%
Backward Fill method
This is just opposite of forward fill method.In this method we will fill the NaN value of a dataframe
with the value in the same column but next row value like if we have NaN in temp column in 2th row 
then we will fill it with data in 3th row in the same column.

This can be implemented by fillna ( method = "bfill")

# %%
#print(df)

# %%
back_fill=df.fillna(method="bfill")# null should filled with back  vales
back_fill
# Out:
#             s.no  temparature  winspeed    event
# day
# 2019-01-02     1         30.0      12.0     rain
# 2019-01-02     1         43.0      14.0     rain
# 2019-01-03     2         43.0      13.0     rain
# 2019-01-04     3         55.0      10.0  fullair
# 2019-01-05     4         66.0      10.0     cold
# 2019-01-06     5         34.0      15.0     cold
# 2019-01-07     6         89.0      17.0  fullair
# 2019-01-08     7         89.0       9.0     cold
# 2019-01-09     8         90.0       9.0  fullair
# 2019-01-10     9         90.0      11.0     cold
# 2019-01-11    10         65.0      20.0  fullair
# 2019-01-12    11          NaN      20.0  fullair

# %%
Forward Fill method
In various cases filling all NaN with same value leads to wrong conclusion. 
So you want to fill all the NaN of respective columns with data similar to that column. 
In the previous example we can see that filling zero in "day" column is not meaningful 
because zero does not denote any condition of day.What if we can fill the data similar 
to the respective columns. In the forward fill method we fill the value of NaN with the 
previous value of the same column like if we have NaN value in temp column in fourth row 
then the fourth row NaN value of temp column will be filled with the value of third row value
of same column in this method

This method can be implemented by

fillna ( method =" ffill ")

# %%
for_fill=df.fillna(method="ffill") # null values should filled with previous values
for_fill
# Out:
#             s.no  temparature  winspeed    event
# day
# 2019-01-02     1         30.0      12.0     rain
# 2019-01-02     1         30.0      14.0     rain
# 2019-01-03     2         43.0      13.0     rain
# 2019-01-04     3         55.0      13.0  fullair
# 2019-01-05     4         66.0      10.0  fullair
# 2019-01-06     5         34.0      15.0     cold
# 2019-01-07     6         34.0      17.0  fullair
# 2019-01-08     7         89.0      17.0     cold
# 2019-01-09     8         89.0       9.0  fullair
# 2019-01-10     9         90.0      11.0     cold
# 2019-01-11    10         65.0      11.0     cold
# 2019-01-12    11         65.0      20.0  fullair

# %%
limit=m :
If your dataframe is having "n" continuous NaN values and you want only "m" 
continuous NaN to fill by forward fill method or backward fill method then you can
fill the m countinuous NaN by passing as extra argument in
fillna(method="ffill",limit=m)

# %%
lm_df=df.fillna(0,limit=2)
lm_df
# Out:
#             s.no  temparature  winspeed    event
# day
# 2019-01-02     1         30.0      12.0     rain
# 2019-01-02     1          0.0      14.0        0
# 2019-01-03     2         43.0      13.0     rain
# 2019-01-04     3         55.0       0.0  fullair
# 2019-01-05     4         66.0      10.0        0
# 2019-01-06     5         34.0      15.0     cold
# 2019-01-07     6          0.0      17.0  fullair
# 2019-01-08     7         89.0       0.0     cold
# 2019-01-09     8          NaN       9.0  fullair
# 2019-01-10     9         90.0      11.0     cold
# 2019-01-11    10         65.0       NaN      NaN
# 2019-01-12    11          NaN      20.0  fullair

# %%
d1=pd.DataFrame({"temp":[34,27,45],"humidity":[45,23,14]})
d1
# Out:
#    temp  humidity
# 0    34        45
# 1    27        23
# 2    45        14

# %%
# replacing with single value
import numpy as np
n1=d1.replace(27,value=34)
n1
# Out:
#    temp  humidity
# 0    34        45
# 1    34        23
# 2    45        14
