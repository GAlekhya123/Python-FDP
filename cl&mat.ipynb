# %%
import pandas as pd
df = pd.read_csv("weather.csv")
df.head()
# Out:
#    s.no       day  temparature  winspeed    event
# 0     1  1/2/2019         30.0      12.0     rain
# 1     1  1/2/2019          NaN      14.0      NaN
# 2     2  1/3/2019         43.0      13.0     rain
# 3     3  1/4/2019         55.0       NaN  fullair
# 4     4  1/5/2019         66.0      10.0      NaN

# %%
df.set_index('day',inplace=True)
df
# Out:
#            s.no  temparature  winspeed    event
# day
# 1/2/2019      1         30.0      12.0     rain
# 1/2/2019      1          NaN      14.0      NaN
# 1/3/2019      2         43.0      13.0     rain
# 1/4/2019      3         55.0       NaN  fullair
# 1/5/2019      4         66.0      10.0      NaN
# 1/6/2019      5         34.0      15.0     cold
# 1/7/2019      6          NaN      17.0  fullair
# 1/8/2019      7         89.0       NaN     cold
# 1/9/2019      8          NaN       9.0  fullair
# 1/10/2019     9         90.0      11.0     cold
# 1/11/2019    10         65.0       NaN      NaN
# 1/12/2019    11          NaN      20.0  fullair

# %%
column_fill=df.fillna({"temperature":0,"windspeed":0,"event":"no event"})
column_fill
# Out:
#            s.no  temparature  winspeed     event
# day
# 1/2/2019      1         30.0      12.0      rain
# 1/2/2019      1          NaN      14.0  no event
# 1/3/2019      2         43.0      13.0      rain
# 1/4/2019      3         55.0       NaN   fullair
# 1/5/2019      4         66.0      10.0  no event
# 1/6/2019      5         34.0      15.0      cold
# 1/7/2019      6          NaN      17.0   fullair
# 1/8/2019      7         89.0       NaN      cold
# 1/9/2019      8          NaN       9.0   fullair
# 1/10/2019     9         90.0      11.0      cold
# 1/11/2019    10         65.0       NaN  no event
# 1/12/2019    11          NaN      20.0   fullair

# %%
Backward Fill method
This is just opposite of forward fill method.In this method we will fill the NaN value 
of a dataframe with the value in the same column but next row value like if we have NaN 
in temp column in 4th row then we will fill it with data in 5th row in the same column.

This can be implemented by fillna ( method = "bfill")

# %%
back_fill=df.fillna(method="bfill")# null should filled with back  vales
back_fill
# Out:
#            s.no  temparature  winspeed    event
# day
# 1/2/2019      1         30.0      12.0     rain
# 1/2/2019      1         43.0      14.0     rain
# 1/3/2019      2         43.0      13.0     rain
# 1/4/2019      3         55.0      10.0  fullair
# 1/5/2019      4         66.0      10.0     cold
# 1/6/2019      5         34.0      15.0     cold
# 1/7/2019      6         89.0      17.0  fullair
# 1/8/2019      7         89.0       9.0     cold
# 1/9/2019      8         90.0       9.0  fullair
# 1/10/2019     9         90.0      11.0     cold
# 1/11/2019    10         65.0      20.0  fullair
# 1/12/2019    11          NaN      20.0  fullair

# %%
Forward Fill method
In various cases filling all NaN with same value leads to wrong conclusion.
So you want to fill all the NaN of respective columns with data similar to that column.
In the previous example we can see that filling zero in "day" column is not meaningful because 
zero does not denote any condition of day.What if we can fill the data similar to the respective
columns. In the forward fill method we fill the value of NaN with the previous value of the same
column like if we have NaN value in temp column in fourth row then the fourth row NaN value of temp
column will be filled with the value of third row value of same column in this method

This method can be implemented by

fillna ( method =" ffill ")

# %%
for_fill=df.fillna(method="ffill") # null values should filled with previous values
for_fill
# Out:
#            s.no  temparature  winspeed    event
# day
# 1/2/2019      1         30.0      12.0     rain
# 1/2/2019      1         30.0      14.0     rain
# 1/3/2019      2         43.0      13.0     rain
# 1/4/2019      3         55.0      13.0  fullair
# 1/5/2019      4         66.0      10.0  fullair
# 1/6/2019      5         34.0      15.0     cold
# 1/7/2019      6         34.0      17.0  fullair
# 1/8/2019      7         89.0      17.0     cold
# 1/9/2019      8         89.0       9.0  fullair
# 1/10/2019     9         90.0      11.0     cold
# 1/11/2019    10         65.0      11.0     cold
# 1/12/2019    11         65.0      20.0  fullair

# %%
limit=m :
If your dataframe is having "n" continuous NaN values and you want only "m" continuous NaN to
fill by forward fill method or backward fill method then you can fill the m countinuous NaN by
passing as extra argument in
fillna(method="ffill",limit=m)

# %%
lm_df=df.fillna(0,limit=2)
lm_df
# Out:
#            s.no  temparature  winspeed    event
# day
# 1/2/2019      1         30.0      12.0     rain
# 1/2/2019      1          0.0      14.0        0
# 1/3/2019      2         43.0      13.0     rain
# 1/4/2019      3         55.0       0.0  fullair
# 1/5/2019      4         66.0      10.0        0
# 1/6/2019      5         34.0      15.0     cold
# 1/7/2019      6          0.0      17.0  fullair
# 1/8/2019      7         89.0       0.0     cold
# 1/9/2019      8          NaN       9.0  fullair
# 1/10/2019     9         90.0      11.0     cold
# 1/11/2019    10         65.0       NaN      NaN
# 1/12/2019    11          NaN      20.0  fullair

# %% [markdown]
# ### Droping a null values

# %%
input_df=pd.read_csv("weather.csv")
print(input_df)
drop_df=input_df.dropna()# will drop the null values
drop_df
# Out:
#     s.no        day  temparature  winspeed    event
# 0      1   1/2/2019         30.0      12.0     rain
# 1      1   1/2/2019          NaN      14.0      NaN
# 2      2   1/3/2019         43.0      13.0     rain
# 3      3   1/4/2019         55.0       NaN  fullair
# 4      4   1/5/2019         66.0      10.0      NaN
# 5      5   1/6/2019         34.0      15.0     cold
# 6      6   1/7/2019          NaN      17.0  fullair
# 7      7   1/8/2019         89.0       NaN     cold
# 8      8   1/9/2019          NaN       9.0  fullair
# 9      9  1/10/2019         90.0      11.0     cold
# 10    10  1/11/2019         65.0       NaN      NaN
# 11    11  1/12/2019          NaN      20.0  fullair
#    s.no        day  temparature  winspeed event
# 0     1   1/2/2019         30.0      12.0  rain
# 2     2   1/3/2019         43.0      13.0  rain
# 5     5   1/6/2019         34.0      15.0  cold
# 9     9  1/10/2019         90.0      11.0  cold

# %% [markdown]
# #### Replace the missing data

# %%
d1=pd.DataFrame({"temp":[34,np.nan,45],"humidity":[45,23,14]})
d1
# Out:
#    temp  humidity
# 0  34.0        45
# 1   NaN        23
# 2  45.0        14

# %%
# replacing with single value
import numpy as np
n1=d1.replace(np.NaN,value=27)
n1
# Out:
#    temp  humidity
# 0  34.0        45
# 1  27.0        23
# 2  45.0        14

# %% [markdown]
# #### Data visulization:
# - matplotlib
# - seaborn
# #### Matplotlib:
# - matplotlib is a one of the best python library for data visulization
# - it is written by john D Hunter in 2003
# #### Different types of plots:
# - Lineplot
# - Scatterplot
# - Bar plot
# - Box plot
# - Histogram plot : 1D data visulization
# - Pie plot
#
# - how to read a image and how to display image in matplotlib
#
# - how to save the image

# %%
# import the lib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Line plot:

# %%
x=[1,2,3,4]
y=[1,2,3,4]

plt.plot(x,y)
plt.show()

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.plot(x,y)
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(x,y,color='g')

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r-*')

# %%
plt.plot(x,y,color='#008000')

# %%
plt.plot(x,y,'r',linestyle='dashed')

# %%
plt.plot(x,y,'g^',markersize=12)

# %%
plt.plot(x,y,'g^',markersize=12)
plt.title("This is line plot")
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x=np.linspace(0,4,50)
plt.plot(x,x,'g',label="this is label one")
plt.plot(x,x**3,'m',label="this is label two")
#plt.legend(loc='upper right')
plt.legend(loc=6)
plt.show()

# %%
x=np.linspace(0,4,50)
plt.plot(x,x,'g',label="this is label one")
plt.plot(x,x**3,'m',label="this is label two")
plt.legend(loc=9)
plt.show()

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.sin(x),'r',linestyle='--')
plt.plot(x,np.cos(x))
plt.title("sin and cos waves")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# #### Scatter plots:
# - Display the data in points

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y,color='m',marker='*')
plt.show()

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,c='b')
plt.scatter(x,y,c='m')
plt.show()

# %% [markdown]
# subplots:
# syntax: plt.subplots(row,column,pos)

# %%
plt.subplots(2,2) # 2 rows and 2 columns
plt.show()

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.subplot(2,2,1)  # 2 rows,2 columns and 1 position
plt.plot(x,y,'r*')

plt.subplot(2,2,2)
plt.plot(x,y,'g--')

plt.subplot(2,2,3)
plt.plot(x,y,'b-')

plt.subplot(2,2,4)
plt.plot(x,x*y,'yo')

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.subplot(1,1,1)  # 2 rows,2 columns and 1 position
plt.plot(x,y,'r*')

# plt.subplot(1,2,2)  # 2 rows,2 columns and 1 position
# plt.plot(x,y,'r*')

# %%
x=np.array([2,4,6,8,10,12,14,16])
plt.plot(x,x**2,'b--',label="dashed line")
plt.plot(x,x**2.2,'rs',label='squared line')
plt.plot(x,x**2.4,'g^',label='traiangle')
plt.legend()
plt.grid()
plt.show()

# %%
#Bar plot

x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.bar(x,y,color='g')
plt.show()

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])
plt.bar(x,y,width=5)
plt.show()

# %%
x=['naga lakshmi','sarayu','siva','venkata sai','hema']
y=[89,90,100,79,80]

plt.bar(x,y)
plt.show()

# %%
x=['naga lakshmi','sarayu','siva','venkata sai','hema']
y=[89,90,100,79,80]

plt.bar(x,y)

for a,b in zip(x,y):
    #plt.text(a,b,str(b))
    #print(b)
    plt.text(a,b,str(b))

plt.show()

# %%
# display the bar graph in horizontal
x=['naga lakshmi','sarayu','siva','venkata sai','hema']
y=[89,90,100,79,80]
plt.barh(x,y)
for a,b in zip(y,x):
    plt.text(a,b,str(a))

plt.show()

# %%
b=[20,35,30,35,27,40]
g=[25,32,34,15,20,32]

i=np.arange(0,6)

p1=plt.bar(i,b,width=0.5)
p2=plt.bar(i,g,width=0.5,bottom=b)

plt.xlabel("class rooms")
plt.ylabel("strenght")
plt.title("mana college")
plt.xticks(i,('c1','c2','c3','c4','c5','c6'))
plt.yticks(np.arange(0,90,10))

plt.legend((p1[0],p2[0]),('boys','girls'))
plt.show()

# %%
b=[20,30,40,50]
g=[10,30,80,60]

i=np.arange(0,4)

p1=plt.bar(i,b,width=0.5)
p2=plt.bar(i,g,width=0.5,bottom=b)


plt.xlabel("Class rooms")
plt.ylabel("Strength")
plt.title("Our College")


plt.xticks(i,('c1','c2','c3','c4'))
plt.yticks(np.arange(0,150,10))

plt.legend((p1[0],p2[0]),("boys","girls"))
plt.show()

# %% [markdown]
# Hist plot:
# for 1D array visulization we can you hist plots
# Frequency distribution data

# %%
x=np.random.randn(1000)
plt.hist(x,histtype='step')
plt.show()

# %%
x=np.random.randn(1000)
plt.hist(x)
plt.show()

# %%
help(plt.hist)

# %%
Box plot:
this is also knows as whisker plot
it contains min value,max value, first quartile, median, third quartaile

# %%
data=np.random.normal(100,20,200)
plt.boxplot(data)
plt.show()

# %%
a=np.random.randint(50,100,10)
b=np.random.randint(40,90,10)
c=np.random.randint(30,100,10)

plt.boxplot([a,b,c],labels=['b1','b2','b3'])
plt.show()

# %%
Pie plot

# %%
labels=['python','c','c++','java']
size=[100,200,300,450]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
plt.pie(size,labels=labels,colors=colors,autopct="%1.2f%%")
plt.axis('equal')
plt.show()

# %%
labels=['python','c','c++','java']
size=[100,200,300,450]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(1,0,0,0)
plt.pie(size,labels=labels,explode=explode,colors=colors,autopct="%1.2f%%")
plt.axis('equal')
plt.show()

# %%
save plot

# %%
labels=['python','c','c++','java']
size=[100,200,300,450]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(1,0,0,0)
plt.pie(size,labels=labels,explode=explode,colors=colors,autopct="%1.2f%%")  #ex: 234.56
plt.axis('equal')
plt.savefig("pieplot2.jpg") #d://folder/filename.png
plt.show()

# %%
Read the image

# %%
a=plt.imread("flower.jpeg")
a
# Out:
# array([[[122, 138, 200],
#         [ 88, 104, 166],
#         [ 87, 103, 165],
#         ...,
#         [ 63,  62,  94],
#         [ 63,  62,  94],
#         [ 63,  62,  94]],
#
#        [[124, 140, 202],
#         [ 90, 106, 168],
#         [ 87, 103, 165],
#         ...,
#         [ 63,  62,  94],
#         [ 63,  62,  94],
#         [ 63,  62,  94]],
#
#        [[127, 143, 205],
#         [ 94, 110, 172],
#         [ 86, 102, 164],
#         ...,
#         [ 64,  63,  95],
#         [ 64,  63,  95],
#         [ 64,  63,  95]],
#
#        ...,
#
#        [[ 74,  96,  50],
#         [ 72,  93,  52],
#         [ 64,  86,  47],
#         ...,
#         [160, 170, 110],
#         [163, 173, 113],
#         [160, 170, 110]],
#
#        [[ 68,  89,  48],
#         [ 75,  96,  57],
#         [ 72,  94,  58],
#         ...,
#         [120, 129,  66],
#         [149, 158,  93],
#         [170, 179, 114]],
#
#        [[ 58,  79,  40],
#         [ 73,  93,  56],
#         [ 76,  97,  64],
# ...

# %%
plt.imshow(a)
plt.figure(figsize=(12,8))
plt.show()
